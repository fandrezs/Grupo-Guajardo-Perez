# %%
import pandas as pd
import altair as alt

df = pd.read_csv("/content/DatosGPPlay.csv", sep=",")

df.head()
# Out:
#       Compañia                              Videojuego   Año Consola/PC  \
# 0  Naughty Dog                         Crash Bandicoot  1996        PS1
# 1  Naughty Dog  Crash Bandicoot 2: Cortex Strikes Back  1997        PS1
# 2  Naughty Dog               Crash Bandicoot 3: Warped  1998        PS1
# 3  Naughty Dog                       Crash Team Racing  1999        PS1
# 4  Naughty Dog  Jak and Daxter: The Precursor´s Legacy  2001        PS2
#
#   N° Trabajadores Tamaño del juego (Aprox.)  \
# 0              84                    428 MB
# 1             122                  71.19 MB
# 2             204                  76.77 MB
# 3             199                  267.8 MB
# 4             277                    977 MB
#
#   Original/Remaster/Remake/Expansión Estética Puntaje Medio Críticas (1-100)
# 0                          Original   Cartoon                             80
# 1                          Original   Cartoon                             89
# ...
